# %%
from datetime import date

name = input('Enter your name: ')
year_of_birth = int(input('Enter your birth year: '))

current_year = date.today().year
age = current_year - year_of_birth

print(f"Hello {name}, you are {age} years old.")
# Out:
# Hello lokok, you are 2003 years old.

# %%
txt = 'LMaasleitbtui'
print(txt[::2])
print(txt[1::2])

even=txt[::2]
odd=txt[1::2]   
print(even)
print(odd)
# Out:
# Lasetti
# Malibu
# Lasetti
# Malibu

# %%
txt = 'MsaatmiazD'
even= txt[::2]
odd= txt[1::2]
print(even)
print(odd)

car1=txt[::2]
car2=txt[1::2]
print(car1,car2)
# Out:
# Matiz
# samaD
# Matiz samaD

# %%
txt = "I'am John. I am from London"
area = txt.split('from ')[1]

print(area)
# Out:
# London

# %%
txt=input('enter a string ')
reserved_txt=txt[::-1]
print(reserved_txt, 'is reserved string')
# Out:
# lokkol is reserved string

# %%
text = input('enter a string ')
vowels = 'aeiouAEIOU'
count=0
for char in text:
    if char in vowels:
        count += 1

# %%
numbers = input('Enter numbers separated by spaces')
num_list=[int(x) for x in numbers.split()]
max_value=max(num_list)
print('The maximum value is', max_value)
# Out:
# The maximum value is 9

# %%
word = input('Enter a word: ')
word = word.lower()

if word == word[::-1]:
    print('Yes, it is a palindrome')
else:
    print('No, it is not a palindrome')
# Out:
# Yes, it is a palindrome

# %%
email = input ('enter your email address: ')
domain = email.split('@')[1]
print('Your domain is:', domain)
# Out:
# Your domain is: amail

# %%
import random
import string

letters = string.ascii_letters
digits = string.digits
special_chars = string.punctuation


all_chars = letters + digits + special_chars

length = int(input("Enter desired password length: "))


password = ''.join(random.choice(all_chars) for _ in range(length))

print("Your generated password is:", password)
# Out:
# Your generated password is: acjaBm!aSusFD>onhduXemmRM|c~DD3hu3K0?lEm4:Tp)yoN!Bo9sCvsn+"3]a1)]=>w<&1RL1k<z.j,@^&}jk$l}:*490&I*KAKfPC''[/v\IIOwb|U$CdC%P#^:O]b#(O4terV)(ppBM#-`HGXEFD`~[#@-P{g)V{MpF;xXAuNDr@<0R7'2-XD7SJ@g_O3GQ<I@Jmt~U2UirrBiOxuT*U&9)g|Qjb5U[/5tsmm-#nt`AdKY!(c:T5zUSu3Xx|EQNk)[)&974\bBDhU:}K|d,zG=[IHQ^yiU2OA}|Y've-2fw-@c+i]p&-+]`F|=n%VP,>cYz_amv5jQB#Bl<oLAS!)]5`b(GLY%$fFsRIj4+QJL1cy/yZCA6(:i.U0kfX_0TUkW{cnR/)I`(+-M788z#q$bq1a~]G9=fo!awW/>@+-F!9h0\1A9qI)fWg6Nj=@Bh{ECp{8TD81FASB2X\?][O25(4W9'XC~Dt1A1I5d_E:<N=+n[n)+qiwt5=::>:`nNJaq-q7I9dP93EW&6PXRIG%f3y-~/*0|;g7:%+h=N6I<1c|NQB5s&y<N]x]X:!n3>Ql\<QXP9H,@N;/P\m6Z''vFo.N$$t.<'rL~t]Exzd=5}oe=]DwP:lV;"DPi}2qz*=-5O0c8$f<0=kEc(C!egx$s}+5`qSLV@;F+8wywChZI[05ls|~v)\]I8-0)$]SIC^3>PZgNS"a|Xhz#Oz@ya*+FvCTAs'|Em~<:90XcX{;Nb&-chPY[~.BD4pi(@yoL<)